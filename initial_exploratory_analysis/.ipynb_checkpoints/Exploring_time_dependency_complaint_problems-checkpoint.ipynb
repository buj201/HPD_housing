# %% [markdown]
# The purpose of this analysis is to explore the time dependency of complaint problem status. Essentially, we're trying to answer the questions:
# * What is the distribution of closed complaint problems in the HPD Complaint Problems dataset?
# * What is the distribution of open complaint problems in the HPD Complaint Problems dataset?

# %%
import pandas as pd
import numpy as np
import re

### 

def get_statusid_and_date_date():
    query = ("https://data.cityofnewyork.us/resource/gp4p-wib8.json?"
             "$select=statusdate,%20statusid"
             "&$limit=1000&$order=:id&$offset=0")
    statusid_and_date = pd.read_json(query)
    print statusid_and_date[0:10]
    more_data = True
    i=1
    while more_data == True:
        query = ("https://data.cityofnewyork.us/resource/gp4p-wib8.json?"
             "$select=statusdate,%20statusid"
             "&$limit=1000&$order=:id&$offset=" + str(i*1000))
        data_page = pd.read_json(query)
        statusid_and_date = pd.concat([statusid_and_date, data_page],ignore_index=True)
        print 'Currently have ', len(statusid_and_date), ' records'
        i +=1
        if len(data_page) < 1000:
            more_data = False
    return statusid_and_date

statusid_and_date = get_statusid_and_date_date()
# Out:
#                 statusdate  statusid
# 0  2015-07-16T00:00:00.000         2
# 1  2015-07-16T00:00:00.000         2
# 2  2015-07-16T00:00:00.000         2
# 3  2014-07-29T00:00:00.000         2
# 4  2014-08-04T00:00:00.000         2
# 5  2014-08-04T00:00:00.000         2
# 6  2014-08-04T00:00:00.000         2
# 7  2014-08-22T00:00:00.000         2
# 8  2014-07-29T00:00:00.000         2
# 9  2014-07-29T00:00:00.000         2
# Currently have  2000  records
# Currently have  3000  records
# Currently have  4000  records
# Currently have  5000  records
# Currently have  6000  records
# Currently have  7000  records
# Currently have  8000  records
# Currently have  9000  records
# Currently have  10000  records
# Currently have  11000  records
# Currently have  12000  records
# Currently have  13000  records
# Currently have  14000  records
# Currently have  15000  records
# Currently have  16000  records
# Currently have  17000  records
# Currently have  18000  records
# Currently have  19000  records
# Currently have  20000  records
# Currently have  21000  records
# Currently have  22000  records
# Currently have  23000  records
# Currently have  24000  records
# Currently have  25000  records
# Currently have  26000  records
# Currently have  27000  records
# Currently have  28000  records
# Currently have  29000  records
# Currently have  30000  records
# Currently have  31000  records
# Currently have  32000  records
# Currently have  33000  records
# Currently have  34000  records
# Currently have  35000  records
# Currently have  36000  records
# Currently have  37000  records
# Currently have  38000  records
# Currently have  39000  records
# Currently have  40000  records
# Currently have  41000  records
# Currently have  42000  records
# Currently have  43000  records
# Currently have  44000  records
# Currently have  45000  records
# Currently have  46000  records
# Currently have  47000  records
# Currently have  48000  records
# Currently have  49000  records
# Currently have  50000  records
# Currently have  51000  records
# Currently have  52000  records
# Currently have  53000  records
# Currently have  54000  records
# Currently have  55000  records
# Currently have  56000  records
# Currently have  57000  records
# Currently have  58000  records
# Currently have  59000  records
# Currently have  60000  records
# Currently have  61000  records
# Currently have  62000  records
# Currently have  63000  records
# Currently have  64000  records
# Currently have  65000  records
# Currently have  66000  records
# Currently have  67000  records
# Currently have  68000  records
# Currently have  69000  records
# Currently have  70000  records
# Currently have  71000  records
# Currently have  72000  records
# Currently have  73000  records
# Currently have  74000  records
# Currently have  75000  records
# Currently have  76000  records
# Currently have  77000  records
# Currently have  78000  records
# Currently have  79000  records
# Currently have  80000  records
# Currently have  81000  records
# Currently have  82000  records
# Currently have  83000  records
# Currently have  84000  records
# Currently have  85000  records
# Currently have  86000  records
# Currently have  87000  records
# Currently have  88000  records
# Currently have  89000  records
# Currently have  90000  records
# Currently have  91000  records
# Currently have  92000  records
# Currently have  93000  records
# Currently have  94000  records
# Currently have  95000  records
# Currently have  96000  records
# Currently have  97000  records
# Currently have  98000  records
# Currently have  99000  records
# Currently have  100000  records
# Currently have  101000  records
# Currently have  102000  records
# Currently have  103000  records
# Currently have  104000  records
# Currently have  105000  records
# Currently have  106000  records
# Currently have  107000  records
# Currently have  108000  records
# Currently have  109000  records
# Currently have  110000  records
# Currently have  111000  records
# Currently have  112000  records
# Currently have  113000  records
# Currently have  114000  records
# Currently have  115000  records
# Currently have  116000  records
# Currently have  117000  records
# Currently have  118000  records
# Currently have  119000  records
# Currently have  120000  records
# Currently have  121000  records
# Currently have  122000  records
# Currently have  123000  records
# Currently have  124000  records
# Currently have  125000  records
# Currently have  126000  records
# Currently have  127000  records
# Currently have  128000  records
# Currently have  129000  records
# Currently have  130000  records
# Currently have  131000  records
# Currently have  132000  records
# Currently have  133000  records
# Currently have  134000  records
# Currently have  135000  records
# Currently have  136000  records
# Currently have  137000  records
# Currently have  138000  records
# Currently have  139000  records
# Currently have  140000  records
# Currently have  141000  records
# Currently have  142000  records
# Currently have  143000  records
# Currently have  144000  records
# Currently have  145000  records
# Currently have  146000  records
# Currently have  147000  records
# Currently have  148000  records
# Currently have  149000  records
# Currently have  150000  records
# Currently have  151000  records
# Currently have  152000  records
# Currently have  153000  records
# Currently have  154000  records
# Currently have  155000  records
# Currently have  156000  records
# Currently have  157000  records
# Currently have  158000  records
# Currently have  159000  records
# Currently have  160000  records
# Currently have  161000  records
# Currently have  162000  records
# Currently have  163000  records
# Currently have  164000  records
# Currently have  165000  records
# Currently have  166000  records
# Currently have  167000  records
# Currently have  168000  records
# Currently have  169000  records
# Currently have  170000  records
# Currently have  171000  records
# Currently have  172000  records
# Currently have  173000  records
# Currently have  174000  records
# Currently have  175000  records
# Currently have  176000  records
# Currently have  177000  records
# Currently have  178000  records
# Currently have  179000  records
# Currently have  180000  records
# Currently have  181000  records
# Currently have  182000  records
# Currently have  183000  records
# Currently have  184000  records
# Currently have  185000  records
# Currently have  186000  records
# Currently have  187000  records
# Currently have  188000  records
# Currently have  189000  records
# Currently have  190000  records
# Currently have  191000  records
# Currently have  192000  records
# Currently have  193000  records
# Currently have  194000  records
# Currently have  195000  records
# Currently have  196000  records
# Currently have  197000  records
# Currently have  198000  records
# Currently have  199000  records
# Currently have  200000  records
# Currently have  201000  records
# Currently have  202000  records
# Currently have  203000  records
# Currently have  204000  records
# Currently have  205000  records
# Currently have  206000  records
# Currently have  207000  records
# Currently have  208000  records
# Currently have  209000  records
# Currently have  210000  records
# Currently have  211000  records
# Currently have  212000  records
# Currently have  213000  records
# Currently have  214000  records
# Currently have  215000  records
# Currently have  216000  records
# Currently have  217000  records
# Currently have  218000  records
# Currently have  219000  records
# Currently have  220000  records
# Currently have  221000  records
# Currently have  222000  records
# Currently have  223000  records
# Currently have  224000  records
# Currently have  225000  records
# Currently have  226000  records
# Currently have  227000  records
# Currently have  228000  records
# Currently have  229000  records
# Currently have  230000  records
# Currently have  231000  records
# Currently have  232000  records
# Currently have  233000  records
# Currently have  234000  records
# Currently have  235000  records
# Currently have  236000  records
# Currently have  237000  records
# Currently have  238000  records
# Currently have  239000  records
# Currently have  240000  records
# Currently have  241000  records
# Currently have  242000  records
# Currently have  243000  records
# Currently have  244000  records
# Currently have  245000  records
# Currently have  246000  records
# Currently have  247000  records
# Currently have  248000  records
# Currently have  249000  records
# Currently have  250000  records
# Currently have  251000  records
# Currently have  252000  records
# Currently have  253000  records
# Currently have  254000  records
# Currently have  255000  records
# Currently have  256000  records
# Currently have  257000  records
# Currently have  258000  records
# Currently have  259000  records
# Currently have  260000  records
# Currently have  261000  records
# Currently have  262000  records
# Currently have  263000  records
# Currently have  264000  records
# Currently have  265000  records
# Currently have  266000  records
# Currently have  267000  records
# Currently have  268000  records
# Currently have  269000  records
# Currently have  270000  records
# Currently have  271000  records
# Currently have  272000  records
# Currently have  273000  records
# Currently have  274000  records
# Currently have  275000  records
# Currently have  276000  records
# Currently have  277000  records
# Currently have  278000  records
# Currently have  279000  records
# Currently have  280000  records
# Currently have  281000  records
# Currently have  282000  records
# Currently have  283000  records
# Currently have  284000  records
# Currently have  285000  records
# Currently have  286000  records
# Currently have  287000  records
# Currently have  288000  records
# Currently have  289000  records
# Currently have  290000  records
# Currently have  291000  records
# Currently have  292000  records
# Currently have  293000  records
# Currently have  294000  records
# Currently have  295000  records
# Currently have  296000  records
# Currently have  297000  records
# Currently have  298000  records
# Currently have  299000  records
# Currently have  300000  records
# Currently have  301000  records
# Currently have  302000  records
# Currently have  303000  records
# Currently have  304000  records
# Currently have  305000  records
# Currently have  306000  records
# Currently have  307000  records
# Currently have  308000  records
# Currently have  309000  records
# Currently have  310000  records
# Currently have  311000  records
# Currently have  312000  records
# Currently have  313000  records
# Currently have  314000  records
# Currently have  315000  records
# Currently have  316000  records
# Currently have  317000  records
# Currently have  318000  records
# Currently have  319000  records
# Currently have  320000  records
# Currently have  321000  records
# Currently have  322000  records
# Currently have  323000  records
# Currently have  324000  records
# Currently have  325000  records
# Currently have  326000  records
# Currently have  327000  records
# Currently have  328000  records
# Currently have  329000  records
# Currently have  330000  records
# Currently have  331000  records
# Currently have  332000  records
# Currently have  333000  records
# Currently have  334000  records
# Currently have  335000  records
# Currently have  336000  records
# Currently have  337000  records
# Currently have  338000  records
# Currently have  339000  records
# Currently have  340000  records
# Currently have  341000  records
# Currently have  342000  records
# Currently have  343000  records
# Currently have  344000  records
# Currently have  345000  records
# Currently have  346000  records
# Currently have  347000  records
# Currently have  348000  records
# Currently have  349000  records
# Currently have  350000  records
# Currently have  351000  records
# Currently have  352000  records
# Currently have  353000  records
# Currently have  354000  records
# Currently have  355000  records
# Currently have  356000  records
# Currently have  357000  records
# Currently have  358000  records
# Currently have  359000  records
# Currently have  360000  records
# Currently have  361000  records
# Currently have  362000  records
# Currently have  363000  records
# Currently have  364000  records
# Currently have  365000  records
# Currently have  366000  records
# Currently have  367000  records
# Currently have  368000  records
# Currently have  369000  records
# Currently have  370000  records
# Currently have  371000  records
# Currently have  372000  records
# Currently have  373000  records
# Currently have  374000  records
# Currently have  375000  records
# Currently have  376000  records
# Currently have  377000  records
# Currently have  378000  records
# Currently have  379000  records
# Currently have  380000  records
# Currently have  381000  records
# Currently have  382000  records
# Currently have  383000  records
# Currently have  384000  records
# Currently have  385000  records
# Currently have  386000  records
# Currently have  387000  records
# Currently have  388000  records
# Currently have  389000  records
# Currently have  390000  records
# Currently have  391000  records
# Currently have  392000  records
# Currently have  393000  records
# Currently have  394000  records
# Currently have  395000  records
# Currently have  396000  records
# Currently have  397000  records
# Currently have  398000  records
# Currently have  399000  records
# Currently have  400000  records
# Currently have  401000  records
# Currently have  402000  records
# Currently have  403000  records
# Currently have  404000  records
# Currently have  405000  records
# Currently have  406000  records
# Currently have  407000  records
# Currently have  408000  records
# Currently have  409000  records
# Currently have  410000  records
# Currently have  411000  records
# Currently have  412000  records
# Currently have  413000  records
# Currently have  414000  records
# Currently have  415000  records
# Currently have  416000  records
# Currently have  417000  records
# Currently have  418000  records
# Currently have  419000  records
# Currently have  420000  records
# Currently have  421000  records
# Currently have  422000  records
# Currently have  423000  records
# Currently have  424000  records
# Currently have  425000  records
# Currently have  426000  records
# Currently have  427000  records
# Currently have  428000  records
# Currently have  429000  records
# Currently have  430000  records
# Currently have  431000  records
# Currently have  432000  records
# Currently have  433000  records
# Currently have  434000  records
# Currently have  435000  records
# Currently have  436000  records
# Currently have  437000  records
# Currently have  438000  records
# Currently have  439000  records
# Currently have  440000  records
# Currently have  441000  records
# Currently have  442000  records
# Currently have  443000  records
# Currently have  444000  records
# Currently have  445000  records
# Currently have  446000  records
# Currently have  447000  records
# Currently have  448000  records
# Currently have  449000  records
# Currently have  450000  records
# Currently have  451000  records
# Currently have  452000  records
# Currently have  453000  records
# Currently have  454000  records
# Currently have  455000  records
# Currently have  456000  records
# Currently have  457000  records
# Currently have  458000  records
# Currently have  459000  records
# Currently have  460000  records
# Currently have  461000  records
# Currently have  462000  records
# Currently have  463000  records
# Currently have  464000  records
# Currently have  465000  records
# Currently have  466000  records
# Currently have  467000  records
# Currently have  468000  records
# Currently have  469000  records
# Currently have  470000  records
# Currently have  471000  records
# Currently have  472000  records
# Currently have  473000  records
# Currently have  474000  records
# Currently have  475000  records
# Currently have  476000  records
# Currently have  477000  records
# Currently have  478000  records
# Currently have  479000  records
# Currently have  480000  records
# Currently have  481000  records
# Currently have  482000  records
# Currently have  483000  records
# Currently have  484000  records
# Currently have  485000  records
# Currently have  486000  records
# Currently have  487000  records
# Currently have  488000  records
# Currently have  489000  records
# Currently have  490000  records
# Currently have  491000  records
# Currently have  492000  records
# Currently have  493000  records
# Currently have  494000  records
# Currently have  495000  records
# Currently have  496000  records
# Currently have  497000  records
# Currently have  498000  records
# Currently have  499000  records
# Currently have  500000  records
# Currently have  501000  records
# Currently have  502000  records
# Currently have  503000  records
# Currently have  504000  records
# Currently have  505000  records
# Currently have  506000  records
# Currently have  507000  records
# Currently have  508000  records
# Currently have  509000  records
# Currently have  510000  records
# Currently have  511000  records
# Currently have  512000  records
# Currently have  513000  records
# Currently have  514000  records
# Currently have  515000  records
# Currently have  516000  records
# Currently have  517000  records
# Currently have  518000  records
# Currently have  519000  records
# Currently have  520000  records
# Currently have  521000  records
# Currently have  522000  records
# Currently have  523000  records
# Currently have  524000  records
# Currently have  525000  records
# Currently have  526000  records
# Currently have  527000  records
# Currently have  528000  records
# Currently have  529000  records
# Currently have  530000  records
# Currently have  531000  records
# Currently have  532000  records
# Currently have  533000  records
# Currently have  534000  records
# Currently have  535000  records
# Currently have  536000  records
# Currently have  537000  records
# Currently have  538000  records
# Currently have  539000  records
# Currently have  540000  records
# Currently have  541000  records
# Currently have  542000  records
# Currently have  543000  records
# Currently have  544000  records
# Currently have  545000  records
# Currently have  546000  records
# Currently have  547000  records
# Currently have  548000  records
# Currently have  549000  records
# Currently have  550000  records
# Currently have  551000  records
# Currently have  552000  records
# Currently have  553000  records
# Currently have  554000  records
# Currently have  555000  records
# Currently have  556000  records
# Currently have  557000  records
# Currently have  558000  records
# Currently have  559000  records
# Currently have  560000  records
# Currently have  561000  records
# Currently have  562000  records
# Currently have  563000  records
# Currently have  564000  records
# Currently have  565000  records
# Currently have  566000  records
# Currently have  567000  records
# Currently have  568000  records
# Currently have  569000  records
# Currently have  570000  records
# Currently have  571000  records
# Currently have  572000  records
# Currently have  573000  records
# Currently have  574000  records
# Currently have  575000  records
# Currently have  576000  records
# Currently have  577000  records
# Currently have  578000  records
# Currently have  579000  records
# Currently have  580000  records
# Currently have  581000  records
# Currently have  582000  records
# Currently have  583000  records
# Currently have  584000  records
# Currently have  585000  records
# Currently have  586000  records
# Currently have  587000  records
# Currently have  588000  records
# Currently have  589000  records
# Currently have  590000  records
# Currently have  591000  records
# Currently have  592000  records
# Currently have  593000  records
# Currently have  594000  records
# Currently have  595000  records
# Currently have  596000  records
# Currently have  597000  records
# Currently have  598000  records
# Currently have  599000  records
# Currently have  600000  records
# Currently have  601000  records
# Currently have  602000  records
# Currently have  603000  records
# Currently have  604000  records
# Currently have  605000  records
# Currently have  606000  records
# Currently have  607000  records
# Currently have  608000  records
# Currently have  609000  records
# Currently have  610000  records
# Currently have  611000  records
# Currently have  612000  records
# Currently have  613000  records
# Currently have  614000  records
# Currently have  615000  records
# Currently have  616000  records
# Currently have  617000  records
# Currently have  618000  records
# Currently have  619000  records
# Currently have  620000  records
# Currently have  621000  records
# Currently have  622000  records
# Currently have  623000  records
# Currently have  624000  records
# Currently have  625000  records
# Currently have  626000  records
# Currently have  627000  records
# Currently have  628000  records
# Currently have  629000  records
# Currently have  630000  records
# Currently have  631000  records
# Currently have  632000  records
# Currently have  633000  records
# Currently have  634000  records
# Currently have  635000  records
# Currently have  636000  records
# Currently have  637000  records
# Currently have  638000  records
# Currently have  639000  records
# Currently have  640000  records
# Currently have  641000  records
# Currently have  642000  records
# Currently have  643000  records
# Currently have  644000  records
# Currently have  645000  records
# Currently have  646000  records
# Currently have  647000  records
# Currently have  648000  records
# Currently have  649000  records
# Currently have  650000  records
# Currently have  651000  records
# Currently have  652000  records
# Currently have  653000  records
# Currently have  654000  records
# Currently have  655000  records
# Currently have  656000  records
# Currently have  657000  records
# Currently have  658000  records
# Currently have  659000  records
# Currently have  660000  records
# Currently have  661000  records
# Currently have  662000  records
# Currently have  663000  records
# Currently have  664000  records
# Currently have  665000  records
# Currently have  666000  records
# Currently have  667000  records
# Currently have  668000  records
# Currently have  669000  records
# Currently have  670000  records
# Currently have  671000  records
# Currently have  672000  records
# Currently have  673000  records
# Currently have  674000  records
# Currently have  675000  records
# Currently have  676000  records
# Currently have  677000  records
# Currently have  678000  records
# Currently have  679000  records
# Currently have  680000  records
# Currently have  681000  records
# Currently have  682000  records
# Currently have  683000  records
# Currently have  684000  records
# Currently have  685000  records
# Currently have  686000  records
# Currently have  687000  records
# Currently have  688000  records
# Currently have  689000  records
# Currently have  690000  records
# Currently have  691000  records
# Currently have  692000  records
# Currently have  693000  records
# Currently have  694000  records
# Currently have  695000  records
# Currently have  696000  records
# Currently have  697000  records
# Currently have  698000  records
# Currently have  699000  records
# Currently have  700000  records
# Currently have  701000  records
# Currently have  702000  records
# Currently have  703000  records
# Currently have  704000  records
# Currently have  705000  records
# Currently have  706000  records
# Currently have  707000  records
# Currently have  708000  records
# Currently have  709000  records
# Currently have  710000  records
# Currently have  711000  records
# Currently have  712000  records
# Currently have  713000  records
# Currently have  714000  records
# Currently have  715000  records
# Currently have  716000  records
# Currently have  717000  records
# Currently have  718000  records
# Currently have  719000  records
# Currently have  720000  records
# Currently have  721000  records
# Currently have  722000  records
# Currently have  723000  records
# Currently have  724000  records
# Currently have  725000  records
# Currently have  726000  records
# Currently have  727000  records
# Currently have  728000  records
# Currently have  729000  records
# Currently have  730000  records
# Currently have  731000  records
# Currently have  732000  records
# Currently have  733000  records
# Currently have  734000  records
# Currently have  735000  records
# Currently have  736000  records
# Currently have  737000  records
# Currently have  738000  records
# Currently have  739000  records
# Currently have  740000  records
# Currently have  741000  records
# Currently have  742000  records
# Currently have  743000  records
# Currently have  744000  records
# Currently have  745000  records
# Currently have  746000  records
# Currently have  747000  records
# Currently have  748000  records
# Currently have  749000  records
# Currently have  750000  records
# Currently have  751000  records
# Currently have  752000  records
# Currently have  753000  records
# Currently have  754000  records
# Currently have  755000  records
# Currently have  756000  records
# Currently have  757000  records
# Currently have  758000  records
# Currently have  759000  records
# Currently have  760000  records
# Currently have  761000  records
# Currently have  762000  records
# Currently have  763000  records
# Currently have  764000  records
# Currently have  765000  records
# Currently have  766000  records
# Currently have  767000  records
# Currently have  768000  records
# Currently have  769000  records
# Currently have  770000  records
# Currently have  771000  records
# Currently have  772000  records
# Currently have  773000  records
# Currently have  774000  records
# Currently have  775000  records
# Currently have  776000  records
# Currently have  777000  records
# Currently have  778000  records
# Currently have  779000  records
# Currently have  780000  records
# Currently have  781000  records
# Currently have  782000  records
# Currently have  783000  records
# Currently have  784000  records
# Currently have  785000  records
# Currently have  786000  records
# Currently have  787000  records
# Currently have  788000  records
# Currently have  789000  records
# Currently have  790000  records
# Currently have  791000  records
# Currently have  792000  records
# Currently have  793000  records
# Currently have  794000  records
# Currently have  795000  records
# Currently have  796000  records
# Currently have  797000  records
# Currently have  798000  records
# Currently have  799000  records
# Currently have  800000  records
# Currently have  801000  records
# Currently have  802000  records
# Currently have  803000  records
# Currently have  804000  records
# Currently have  805000  records
# Currently have  806000  records
# Currently have  807000  records
# Currently have  808000  records
# Currently have  809000  records
# Currently have  810000  records
# Currently have  811000  records
# Currently have  812000  records
# Currently have  813000  records
# Currently have  814000  records
# Currently have  815000  records
# Currently have  816000  records
# Currently have  817000  records
# Currently have  818000  records
# Currently have  819000  records
# Currently have  820000  records
# Currently have  821000  records
# Currently have  822000  records
# Currently have  823000  records
# Currently have  824000  records
# Currently have  825000  records
# Currently have  826000  records
# Currently have  827000  records
# Currently have  828000  records
# Currently have  829000  records
# Currently have  830000  records
# Currently have  831000  records
# Currently have  832000  records
# Currently have  833000  records
# Currently have  834000  records
# Currently have  835000  records
# Currently have  836000  records
# Currently have  837000  records
# Currently have  838000  records
# Currently have  839000  records
# Currently have  840000  records
# Currently have  841000  records
# Currently have  842000  records
# Currently have  843000  records
# Currently have  844000  records
# Currently have  845000  records
# Currently have  846000  records
# Currently have  847000  records
# Currently have  848000  records
# Currently have  849000  records
# Currently have  850000  records
# Currently have  851000  records
# Currently have  852000  records
# Currently have  852936  records

# %%
statusid_and_date = statusid_and_date.dropna(axis=0)
print (len(statusid_and_date))
# Out:
# 852903

# %%
import time
import re

def just_date(string):
    split_string = re.split(r'T',str(string))
    string = split_string[0] + ' ' + split_string[1]
    return string
 
statusid_and_date['proc_date'] = statusid_and_date.statusdate.map(just_date)
statusid_and_date['proc_date'] = pd.to_datetime(statusid_and_date['proc_date'], errors='coerce')
statusid_and_date = statusid_and_date.dropna(axis=0)

print statusid_and_date[0:8]
# Out:
#                 statusdate  statusid  proc_date
# 0  2015-07-16T00:00:00.000         2 2015-07-16
# 1  2015-07-16T00:00:00.000         2 2015-07-16
# 2  2015-07-16T00:00:00.000         2 2015-07-16
# 3  2014-07-29T00:00:00.000         2 2014-07-29
# 4  2014-08-04T00:00:00.000         2 2014-08-04
# 5  2014-08-04T00:00:00.000         2 2014-08-04
# 6  2014-08-04T00:00:00.000         2 2014-08-04
# 7  2014-08-22T00:00:00.000         2 2014-08-22

# %%
# %matplotlib inline

grouped_status = statusid_and_date.groupby('statusid')
group1 = grouped_status.get_group(1)
group2 = grouped_status.get_group(2)

group1.groupby([group1.proc_date.dt.year, group1.proc_date.dt.month]).count().plot(kind="bar")
group2.groupby([group2.proc_date.dt.year]).count().plot(kind="bar")

# %% [markdown]
# Based on this plots, we conclude:
# * Most closed complaints are from 2014 and 2015- the number of closed complaints included in the dataset from earlier years is negligible.
# * Most open complaints are from the past month. Additionally, as such, we can think of open complaints as unlabeled- the complaint has been recorded in the HPD Complaint Problems dataset,  but it hasn't been dealt with by HPD and as such we do not know the value of our target variable (i.e. will the complaint result in a violation, no violation, no access for inspection, etc.)
